# %%
#installs

pip install pandas
# Out:
#   File "<ipython-input-5-39f4937a5587>", line 3
#     pip install pandas
#         ^
# SyntaxError: invalid syntax

# %%
import json
from textwrap import dedent as d
import pandas as pd
import plotly.graph_objects as go
import numpy as np
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
from dash.dependencies import Input, Output
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-dcdfee18139e> in <module>
#       1 import json
#       2 from textwrap import dedent as d
# ----> 3 import pandas as pd
#       4 import plotly.graph_objects as go
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#### import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from textwrap import dedent as d
import dash_bootstrap_components as dbc

import pandas as pd
import plotly.graph_objs as go

# Step 1. Launch the application
app = dash.Dash()

# Step 2. Import the dataset
st = pd.read_excel('/Users/yolanda/Downloads/data42.xlsx')

# dropdown options
features = st.columns[1:-1]
opts = [{'label' : i, 'value' : i} for i in features]

# range slider options
st['Date'] = pd.to_datetime(st.Date)
dates = ['1955-01-17', '1966-05-17', '1972-08-17', '1979-10-17',
         '1987-01-17', '1995-05-17', '2003-08-17', '2011-10-01', '2020-11-14']

dates2 = ['2020-12-17', '2021-02-17', '2021-04-17', '2021-06-17',
         '2021-08-17', '2021-10-17', '2021-12-17']

# Step 3. Create a plotly figure
trace_1 = go.Scatter(x = st.Date, y = st['Gauteng'],
                    name = 'Gauteng',
                    line = dict(width = 2,
                                color = 'rgb(229, 151, 50)'))

layout = go.Layout(title = 'Drought Time Series Plot',
                   hovermode = 'closest')
fig = go.Figure(data = [trace_1], layout = layout)

red_button_style = {'background-color': '#3aaab2',
                    'color': 'black',
                    'height': '35px',
                    'width': '200px',
                    'fontSize' : '15px',
                    #'margin-top': '400px',
                    'margin-left': '100px',
                   }

# Step 4. Create a Dash layout
app.layout = html.Div([
                # a header and a paragraph
                html.Div([
                    html.H1("Simulation Tool"),
                   
                         ],
                     style = {'padding' : '50px' ,
                              'padding-left' : '35%',
                              'backgroundColor' : '#3aaab2'}),
                # adding a plot
                dcc.Graph(id = 'plot', figure = fig),
        
                # range slider
                html.P([
                    html.Label("Time Period"),
                    dcc.RangeSlider(id = 'slider',
                                    marks = {i : dates[i] for i in range(0, 9)},
                                    min = 0,
                                    max = 8,
                                    value = [1, 7])
                        ], style = {'width' : '80%',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),  
                # dropdown
                html.P([
                    html.Label("Select Province"),
                    dcc.Dropdown(id = 'opt', options = opts,
                                value = opts[0])
                        ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),
                #button
               html.Div(
                    children=[
                    html.Button("Forecast", id="loading-button", style = red_button_style),
                    dcc.Loading(id="loading-output",
                            type="default",
                            children=html.Div(id="loading-output-1")
                                ),
                            ],
                        )
    
                      ])


# Step 5. Add callback functions
@app.callback(Output('plot', 'figure'),
             [Input('opt', 'value'),
             Input('slider', 'value')])

def update_figure(input1, input2):
    # filtering the data
    st2 = st[(st.Date > dates[input2[0]]) & (st.Date < dates[input2[1]])]
    # updating the plot
    trace_1 = go.Scatter(x = st2.Date, y = st2['Gauteng'],
                        name = 'Gauteng',
                        line = dict(width = 2,
                                    color = 'rgb(229, 151, 50)'))
    trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
                        name = input1,
                        line = dict(width = 2,
                                    color = 'rgb(106, 181, 135)'))
    fig = go.Figure(data = [trace_1, trace_2], layout = layout)
    return fig

@app.callback(
    Output("loading-output", "children"), 
    [Input("loading-button", "n_clicks")])


def load_output(n):
    if n == 1:
        time.sleep(5)
        return  html.Div([  
            dcc.Graph(id= 'mpg-scatter',figure=fig1),
                            
            html.Div(className='row', children=[
                        
                html.Div([dcc.Markdown(d("""
                            
                            Click on point in the graph to display value. """)),
            
                          html.Pre(id='hover-data'),
            
                                     
                         ], className='three columns'),
            
                            
            ], style = {'width': '400px',    
                        'fontSize' : '20px',           
                        'padding-left' : '100px',
                        'display': 'inline-block'}, 
                                    
                    ) ,
                    
        ])

    if n == 2:
        time.sleep(5)
        return  html.Div([  
            dcc.Graph(id= 'mpg-scatter',figure=fig2),
                            
            html.Div(className='row', children=[
                        
                html.Div([dcc.Markdown(d("""
                            
                            Click on point in the graph to display value. """)),
            
                          html.Pre(id='hover-data'),
            
                                     
                         ], className='three columns'),
            
                            
            ], style = {'width': '400px',    
                        'fontSize' : '20px',           
                        'padding-left' : '100px',
                        'display': 'inline-block'}, 
                                    
                    ) ,
                    
        ])

        if n == 2:
            time.sleep(5)
            return  html.Div([  
                dcc.Graph(id= 'mpg-scatter',figure=fig2),
                            
                html.Div(className='row', children=[
                        
                    html.Div([dcc.Markdown(d("""
                            
                                Click on point in the graph to display value. """)),
            
                              html.Pre(id='hover-data'),
            
                                     
                             ], className='three columns'),
            
                            
                ], style = {'width': '400px',    
                        'fontSize' : '20px',           
                        'padding-left' : '100px',
                        'display': 'inline-block'}, 
                                    
                        ) ,
                    
            ])
        
    else:
        return None
    
    
@app.callback(
    Output('hover-data', 'children'),
    [Input('mpg-scatter', 'hoverData')])

def display_hover_data(hoverData):
    try: 
        return json.dumps({'Date:':hoverData['points'][0]['x'],
                           'SPEI Index:':hoverData['points'][0]['y'],
                          'Category': 'Severe drought'}, indent = 2)
    except: 
        return None  
# Step 6. Add the server clause
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Nov/2020 13:10:47] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 13:10:47] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 13:10:47] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 13:10:47] "GET /_favicon.ico?v=1.17.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 13:10:48] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-2-c10a458c90a1>", line 109, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# 127.0.0.1 - - [15/Nov/2020 13:10:48] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-2-c10a458c90a1>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# 127.0.0.1 - - [15/Nov/2020 13:10:50] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-2-c10a458c90a1>", line 149, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# 127.0.0.1 - - [15/Nov/2020 13:10:50] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [15/Nov/2020 13:10:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 13:10:52] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 13:10:53] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
working

# %%
#### import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from textwrap import dedent as d

import pandas as pd
import plotly.graph_objs as go

# Step 1. Launch the application
app = dash.Dash()

# Step 2. Import the dataset
st = pd.read_excel('/Users/yolanda/Downloads/data42.xlsx')

# dropdown options
features = st.columns[1:-1]
opts = [{'label' : i, 'value' : i} for i in features]

# range slider options
st['Date'] = pd.to_datetime(st.Date)
dates = ['1955-01-17', '1966-05-17', '1972-08-17', '1979-10-17',
         '1987-01-17', '1995-05-17', '2003-08-17', '2011-10-01', '2020-11-14']

dates2 = ['2020-12-17', '2021-02-17', '2021-04-17', '2021-06-17',
         '2021-08-17', '2021-10-17', '2021-12-17']

# Step 3. Create a plotly figure
trace_1 = go.Scatter(x = st.Date, y = st['Gauteng'],
                    name = 'Gauteng',
                    line = dict(width = 2,
                                color = 'rgb(229, 151, 50)'))

layout = go.Layout(title = 'Drought Time Series Plot',
                   hovermode = 'closest')
fig = go.Figure(data = [trace_1], layout = layout)

red_button_style = {'background-color': '#3aaab2',
                    'color': 'black',
                    'height': '30px',
                    'width': '200px',
                    'fontSize' : '15px',
                    #'margin-top': '400px',
                    'margin-left': '100px',
                   }

# Step 4. Create a Dash layout
app.layout = html.Div([
                # a header and a paragraph
                html.Div([
                    html.H1("Simulation Tool"),
                   
                         ],
                     style = {'padding' : '50px' ,
                              'padding-left' : '35%',
                              'backgroundColor' : '#3aaab2'}),
                # adding a plot
                dcc.Graph(id = 'plot', figure = fig),
    
    
                # dropdown
                html.P([
                    html.Label("Select Province"),
                    dcc.Dropdown(id = 'opt', options = opts,
                                value = opts[0])
                        ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),
                #button
                html.Div(className='submit', children=[

                html.Button('Forecast', id='submit', n_clicks=0, style = red_button_style)
                ]),
    

                # range slider
                html.P([
                    html.Label("Time Period"),
                    dcc.RangeSlider(id = 'slider',
                                    marks = {i : dates[i] for i in range(0, 9)},
                                    min = 0,
                                    max = 8,
                                    value = [1, 7])
                        ], style = {'width' : '80%',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),
    
        dcc.Graph(id= 'mpg-scatter',figure=fig1),
    
    
             html.Div(className='row', children=[
        html.Div([
            dcc.Markdown(d("""
              Click on point in the graph to display value.
            """)),
            html.Pre(id='hover-data'),
        ], className='three columns'),
    ])          
    
                      ])


# Step 5. Add callback functions
@app.callback(Output('plot', 'figure'),
             [Input('opt', 'value'),
             Input('slider', 'value')])

def update_figure(input1, input2):
    # filtering the data
    st2 = st[(st.Date > dates[input2[0]]) & (st.Date < dates[input2[1]])]
    # updating the plot
    trace_1 = go.Scatter(x = st2.Date, y = st2['Gauteng'],
                        name = 'Gauteng',
                        line = dict(width = 2,
                                    color = 'rgb(229, 151, 50)'))
    trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
                        name = input1,
                        line = dict(width = 2,
                                    color = 'rgb(106, 181, 135)'))
    fig = go.Figure(data = [trace_1, trace_2], layout = layout)
    return fig


@app.callback(
    Output('hover-data', 'children'),
    [Input('mpg-scatter', 'hoverData')])

def display_hover_data(hoverData):
    try: 
        return json.dumps({'Date:':hoverData['points'][0]['x'],
                           'Value:':hoverData['points'][0]['y']}, indent = 2)
    except: 
        return None  
# Step 6. Add the server clause
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)

# %% [markdown]
# ### FORECAST

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from statsmodels.tools.eval_measures import rmse
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
dd = st[['Gauteng', 'Date']]
dd=dd.set_index('Date')
dd
# Out:
#              Gauteng
# Date
# 1955-01-01  0.425023
# 1955-02-01  0.829070
# 1955-03-01  1.013218
# 1955-04-01  0.986180
# 1955-05-01  0.491640
# ...              ...
# 2020-06-01 -0.620453
# 2020-07-01 -1.753303
# 2020-08-01 -1.066956
# 2020-09-01 -0.612492
# 2020-10-01 -1.134518
#
# [790 rows x 1 columns]

# %%
train = dd

# %%
train
# Out:
#              Gauteng
# Date
# 1955-01-01  0.425023
# 1955-02-01  0.829070
# 1955-03-01  1.013218
# 1955-04-01  0.986180
# 1955-05-01  0.491640
# ...              ...
# 2020-06-01 -0.620453
# 2020-07-01 -1.753303
# 2020-08-01 -1.066956
# 2020-09-01 -0.612492
# 2020-10-01 -1.134518
#
# [790 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(train)
train = scaler.transform(train)

# %%
n_input = 12
n_features = 1
generator = TimeseriesGenerator(train, train, length=n_input, batch_size=76)

# %%
model = Sequential()
model.add(LSTM(200, activation='relu', input_shape=(n_input, n_features)))
model.add(Dropout(0.15))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit_generator(generator,epochs=30)
# Out:
# Epoch 1/30
# 11/11 [==============================] - 3s 296ms/step - loss: 1.0624
# Epoch 2/30
# 11/11 [==============================] - 1s 102ms/step - loss: 0.8691
# Epoch 3/30
# 11/11 [==============================] - 1s 102ms/step - loss: 0.7510
# Epoch 4/30
# 11/11 [==============================] - 1s 105ms/step - loss: 0.7839
# Epoch 5/30
# 11/11 [==============================] - 1s 104ms/step - loss: 0.7652
# Epoch 6/30
# 11/11 [==============================] - 1s 111ms/step - loss: 0.7565
# Epoch 7/30
# 11/11 [==============================] - 1s 121ms/step - loss: 0.7175
# Epoch 8/30
# 11/11 [==============================] - 2s 142ms/step - loss: 0.6924
# Epoch 9/30
# 11/11 [==============================] - 1s 116ms/step - loss: 0.6477
# Epoch 10/30
# 11/11 [==============================] - 1s 120ms/step - loss: 0.6263
# Epoch 11/30
# 11/11 [==============================] - 1s 121ms/step - loss: 0.5975
# Epoch 12/30
# 11/11 [==============================] - 1s 122ms/step - loss: 0.5686
# Epoch 13/30
# 11/11 [==============================] - 1s 114ms/step - loss: 0.5546
# Epoch 14/30
# 11/11 [==============================] - 1s 120ms/step - loss: 0.5603
# Epoch 15/30
# 11/11 [==============================] - 1s 118ms/step - loss: 0.5303
# Epoch 16/30
# 11/11 [==============================] - 1s 123ms/step - loss: 0.4897
# Epoch 17/30
# 11/11 [==============================] - 1s 107ms/step - loss: 0.5103
# Epoch 18/30
# 11/11 [==============================] - 1s 107ms/step - loss: 0.4972
# Epoch 19/30
# 11/11 [==============================] - 1s 112ms/step - loss: 0.4890
# Epoch 20/30
# 11/11 [==============================] - 1s 107ms/step - loss: 0.5280
# Epoch 21/30
# 11/11 [==============================] - 1s 109ms/step - loss: 0.4990
# Epoch 22/30
# 11/11 [==============================] - 1s 107ms/step - loss: 0.4523
# Epoch 23/30
# 11/11 [==============================] - 2s 137ms/step - loss: 0.4629
# Epoch 24/30
# 11/11 [==============================] - 2s 168ms/step - loss: 0.4557
# Epoch 25/30
# 11/11 [==============================] - 1s 129ms/step - loss: 0.4363
# Epoch 26/30
# 11/11 [==============================] - 1s 115ms/step - loss: 0.4384
# Epoch 27/30
# 11/11 [==============================] - 1s 113ms/step - loss: 0.4328
# Epoch 28/30
# 11/11 [==============================] - 1s 107ms/step - loss: 0.4478
# Epoch 29/30
# 11/11 [==============================] - 1s 109ms/step - loss: 0.4314
# Epoch 30/30
# 11/11 [==============================] - 1s 116ms/step - loss: 0.4429

# %%
pred_list = []

batch = train[-n_input:].reshape((1, n_input, n_features))

for i in range(n_input):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
from pandas.tseries.offsets import DateOffset
add_dates = [dd.index[-1] + DateOffset(months=x) for x in range(0,13) ]
future_dates = pd.DataFrame(index=add_dates[1:],columns=dd.columns)

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index=future_dates[-n_input:].index, columns=['Prediction'])

df_proj = pd.concat([dd,df_predict], axis=1)

# %%
plt.figure(figsize=(20, 5))
#plt.plot(df_proj.index, df_proj['Gauteng'])
plt.plot(df_proj.index, df_proj['Prediction'], color='r')
plt.legend(loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
df_proj
# Out:
#              Gauteng  Prediction
# 1955-01-01  0.425023         NaN
# 1955-02-01  0.829070         NaN
# 1955-03-01  1.013218         NaN
# 1955-04-01  0.986180         NaN
# 1955-05-01  0.491640         NaN
# ...              ...         ...
# 2021-06-01       NaN   -0.638180
# 2021-07-01       NaN   -0.716106
# 2021-08-01       NaN   -0.728118
# 2021-09-01       NaN   -0.714265
# 2021-10-01       NaN   -0.699657
#
# [802 rows x 2 columns]

# %%
df_proj.shape
# Out:
# (802, 2)

# %%
df_proj.iloc[790:802,1].index
# Out:
# DatetimeIndex(['2020-11-01', '2020-12-01', '2021-01-01', '2021-02-01',
#                '2021-03-01', '2021-04-01', '2021-05-01', '2021-06-01',
#                '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
plot_data = [

    go.Scatter(
        x=df_proj.iloc[790:802,1].index,
        y=df_proj.iloc[790:802,1].values,
        name='prediction'
    )
]

plot_layout = go.Layout(
        title='Free State Drought Prediction'
    )
fig1 = go.Figure(data=plot_data, layout=plot_layout)

# %%
#import plotly as ply
#ply.offline.plot(fig)

# %%
app.layout = html.Div([

                #button
                html.Div(className='submit', children=[

                html.Button('Forecast', id='button', n_clicks=0),
                html.Div(id='my-div')
                ]),

                #graph
                dcc.Graph(id= 'mpg-scatter',figure=fig),
    
                #hoverdata
                html.Div([
                    dcc.Markdown(id='hoverdata-text')
                ],style={'width':'50%','display':'inline-block'})
])

@app.callback(
    Output(component_id='my-div', component_property='children'),
    [Input('button', 'n_clicks')],
   )

def update_output_div(n_clicks, input_value):
    return 'You\'ve entered "{}" and clicked {} times'.format(input_value, n_clicks)


@app.callback(Output('hoverdata-text','children'),
             [Input('mpg-scatter','hoverData')])

def callback_stats(hoverData):
    return str(hoverData)


# Step 6. Add the server clause
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)

# %%
#### import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from textwrap import dedent as d

import pandas as pd
import plotly.graph_objs as go

# Step 1. Launch the application
app = dash.Dash()

# Step 2. Import the dataset
st = pd.read_excel('/Users/yolanda/Downloads/data42.xlsx')

# dropdown options
features = st.columns[1:-1]
opts = [{'label' : i, 'value' : i} for i in features]

# range slider options
st['Date'] = pd.to_datetime(st.Date)
dates = ['1955-01-17', '1966-05-17', '1972-08-17', '1979-10-17',
         '1987-01-17', '1995-05-17', '2003-08-17', '2011-10-01', '2020-11-14']

dates2 = ['2020-12-17', '2021-02-17', '2021-04-17', '2021-06-17',
         '2021-08-17', '2021-10-17', '2021-12-17']

# Step 3. Create a plotly figure
trace_1 = go.Scatter(x = st.Date, y = st['Gauteng'],
                    name = 'Gauteng',
                    line = dict(width = 2,
                                color = 'rgb(229, 151, 50)'))

layout = go.Layout(title = 'Drought Time Series Plot',
                   hovermode = 'closest')
fig = go.Figure(data = [trace_1], layout = layout)

red_button_style = {'background-color': '#3aaab2',
                    'color': 'black',
                    'height': '30px',
                    'width': '200px',
                    'fontSize' : '15px',
                    #'margin-top': '400px',
                    'margin-left': '100px',
                   }

# Step 4. Create a Dash layout
app.layout = html.Div([
                # a header and a paragraph
                html.Div([
                    html.H1("Simulation Tool"),
                   
                         ],
                     style = {'padding' : '50px' ,
                              'padding-left' : '35%',
                              'backgroundColor' : '#3aaab2'}),
                # adding a plot
                dcc.Graph(id = 'plot', figure = fig),
    
                # dropdown
                html.P([
                    html.Label("Select Province"),
                    dcc.Dropdown(id = 'opt', options = opts,
                                value = opts[0])
                        ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),
                #button
               html.Div(
                    children=[
                    dbc.Button("Forecast", id="loading-button", style = red_button_style),
                    dcc.Loading(id="loading-output",
                            type="default",
                            children=html.Div(id="loading-output-1")
                                ),
                            ],
                        ),
    

                # range slider
                html.P([
                    html.Label("Time Period"),
                    dcc.RangeSlider(id = 'slider',
                                    marks = {i : dates[i] for i in range(0, 9)},
                                    min = 0,
                                    max = 8,
                                    value = [1, 7])
                        ], style = {'width' : '80%',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),

        dcc.Graph(id= 'mpg-scatter',figure=fig1),
    
    
             html.Div(className='row', children=[
        html.Div([
            dcc.Markdown(d("""
              Click on point in the graph to display value.
            """)),
            html.Pre(id='hover-data'),
        ], className='three columns'),
    ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'} )               
    
                      ])


# Step 5. Add callback functions
@app.callback(Output('plot', 'figure'),
             [Input('opt', 'value'),
             Input('slider', 'value')])

def update_figure(input1, input2):
    # filtering the data
    st2 = st[(st.Date > dates[input2[0]]) & (st.Date < dates[input2[1]])]
    # updating the plot
    trace_1 = go.Scatter(x = st2.Date, y = st2['Gauteng'],
                        name = 'Gauteng',
                        line = dict(width = 2,
                                    color = 'rgb(229, 151, 50)'))
    trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
                        name = input1,
                        line = dict(width = 2,
                                    color = 'rgb(106, 181, 135)'))
    fig = go.Figure(data = [trace_1, trace_2], layout = layout)
    return fig

@app.callback(
    Output("loading-output", "children"), [Input("loading-button", "n_clicks")]
)
def load_output(n):
    if n:
        time.sleep(5)
        
        return  html.Div([
                    html.P("SPEI Index Forecasted"),],
                     style = {'position' : 'absolute' ,
                              "top": '730px',
                              'padding-left' : '35%'})

@app.callback(
    Output('hover-data', 'children'),
    [Input('mpg-scatter', 'hoverData')])

def display_hover_data(hoverData):
    try: 
        return json.dumps({'Date:':hoverData['points'][0]['x'],
                           'SPEI Index:':hoverData['points'][0]['y'],
                          'Category': 'Moderate drought'}, indent = 2)
    except: 
        return None  
# Step 6. Add the server clause
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Nov/2020 12:39:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:39:59] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:39:59] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:39:59] "GET /_favicon.ico?v=1.17.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:39:59] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 125, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# 127.0.0.1 - - [15/Nov/2020 12:39:59] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [15/Nov/2020 12:39:59] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:02] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:03] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# 127.0.0.1 - - [15/Nov/2020 12:40:04] "POST /_dash-update-component HTTP/1.1" 500 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-38-f2e144608177>", line 137, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# 127.0.0.1 - - [15/Nov/2020 12:40:05] "POST /_dash-update-component HTTP/1.1" 500 -

# %%
 release =     html.Div([  
    
    dcc.Graph(id= 'mpg-scatter',figure=fig1),
    
    
             html.Div(className='row', children=[
        html.Div([
            dcc.Markdown(d("""
              Click on point in the graph to display value.
            """)),
            html.Pre(id='hover-data'),
        ], className='three columns'),
    ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'} )  ])

# %%
#### import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from textwrap import dedent as d

import pandas as pd
import plotly.graph_objs as go

# Step 1. Launch the application
app = dash.Dash()

# Step 2. Import the dataset
st = pd.read_excel('/Users/yolanda/Downloads/data42.xlsx')

# dropdown options
features = st.columns[1:-1]
opts = [{'label' : i, 'value' : i} for i in features]

# range slider options
st['Date'] = pd.to_datetime(st.Date)
dates = ['1955-01-17', '1966-05-17', '1972-08-17', '1979-10-17',
         '1987-01-17', '1995-05-17', '2003-08-17', '2011-10-01', '2020-11-14']

dates2 = ['2020-12-17', '2021-02-17', '2021-04-17', '2021-06-17',
         '2021-08-17', '2021-10-17', '2021-12-17']

# Step 3. Create a plotly figure
trace_1 = go.Scatter(x = st.Date, y = st['Gauteng'],
                    name = 'Gauteng',
                    line = dict(width = 2,
                                color = 'rgb(229, 151, 50)'))

layout = go.Layout(title = 'Drought Time Series Plot',
                   hovermode = 'closest')
fig = go.Figure(data = [trace_1], layout = layout)

red_button_style = {'background-color': '#3aaab2',
                    'color': 'black',
                    'height': '35px',
                    'width': '200px',
                    'fontSize' : '15px',
                    #'margin-top': '400px',
                    'margin-left': '100px',
                   }

# Step 4. Create a Dash layout
app.layout = html.Div([
                # a header and a paragraph
                html.Div([
                    html.H1("Simulation Tool"),
                   
                         ],
                     style = {'padding' : '50px' ,
                              'padding-left' : '35%',
                              'backgroundColor' : '#3aaab2'}),
                # adding a plot
                dcc.Graph(id = 'plot', figure = fig),
        

                # range slider
                html.P([
                    html.Label("Time Period"),
                    dcc.RangeSlider(id = 'slider',
                                    marks = {i : dates[i] for i in range(0, 9)},
                                    min = 0,
                                    max = 8,
                                    value = [1, 7])
                        ], style = {'width' : '80%',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),  
                # dropdown
                html.P([
                    html.Label("Select Province"),
                    dcc.Dropdown(id = 'opt', options = opts,
                                value = opts[0])
                        ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),
                #button
               html.Div(
                    children=[
                    dbc.Button("Forecast", id="loading-button", style = red_button_style),
                    dcc.Loading(id="loading-output",
                            type="default",
                            children=html.Div(id="loading-output-1")
                                ),
                            ],
                        )
           
    
                      ])


# Step 5. Add callback functions
@app.callback(Output('plot', 'figure'),
             [Input('opt', 'value'),
             Input('slider', 'value')])

def update_figure(input1, input2):
    # filtering the data
    st2 = st[(st.Date > dates[input2[0]]) & (st.Date < dates[input2[1]])]
    # updating the plot
    trace_1 = go.Scatter(x = st2.Date, y = st2['Gauteng'],
                        name = 'Gauteng',
                        line = dict(width = 2,
                                    color = 'rgb(229, 151, 50)'))
    trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
                        name = input1,
                        line = dict(width = 2,
                                    color = 'rgb(106, 181, 135)'))
    fig = go.Figure(data = [trace_1, trace_2], layout = layout)
    return fig

@app.callback(
    Output("loading-output", "children"), [Input("loading-button", "n_clicks")]
)
def load_output(n):
    if n:
        time.sleep(5)
        
        return  html.Div([  
    
    dcc.Graph(id= 'mpg-scatter',figure=fig1),
    html.Div(className='row', children=[
    html.Div([dcc.Markdown(d("""
              Click on point in the graph to display value.
            """)),
            html.Pre(id='hover-data'),
            ], className='three columns'),
            ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}, ) ,
             ])

@app.callback(
    Output('hover-data', 'children'),
    [Input('mpg-scatter', 'hoverData')])

def display_hover_data(hoverData):
    try: 
        return json.dumps({'Date:':hoverData['points'][0]['x'],
                           'SPEI Index:':hoverData['points'][0]['y'],
                          'Category': 'Moderate drought'}, indent = 2)
    except: 
        return None  
# Step 6. Add the server clause
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Nov/2020 12:40:16] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:16] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:16] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:16] "GET /_favicon.ico?v=1.17.0 HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:16] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 110, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# 127.0.0.1 - - [15/Nov/2020 12:40:16] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [15/Nov/2020 12:40:17] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# ...
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-40-477ccc312204>", line 122, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# 127.0.0.1 - - [15/Nov/2020 12:40:21] "POST /_dash-update-component HTTP/1.1" 500 -

# %%
#### import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
from textwrap import dedent as d
import dash_bootstrap_components as dbc

import pandas as pd
import plotly.graph_objs as go

# Step 1. Launch the application
app = dash.Dash()

# Step 2. Import the dataset
st = pd.read_excel('/Users/yolanda/Downloads/data42.xlsx')

# dropdown options
features = st.columns[1:-1]
opts = [{'label' : i, 'value' : i} for i in features]

# range slider options
st['Date'] = pd.to_datetime(st.Date)
dates = ['1955-01-17', '1966-05-17', '1972-08-17', '1979-10-17',
         '1987-01-17', '1995-05-17', '2003-08-17', '2011-10-01', '2020-11-14']

dates2 = ['2020-12-17', '2021-02-17', '2021-04-17', '2021-06-17',
         '2021-08-17', '2021-10-17', '2021-12-17']

# Step 3. Create a plotly figure
trace_1 = go.Scatter(x = st.Date, y = st['Gauteng'],
                    name = 'Gauteng',
                    line = dict(width = 2,
                                color = 'rgb(229, 151, 50)'))

layout = go.Layout(title = 'Drought Time Series Plot',
                   hovermode = 'closest')
fig = go.Figure(data = [trace_1], layout = layout)

red_button_style = {'background-color': '#3aaab2',
                    'color': 'black',
                    'height': '35px',
                    'width': '200px',
                    'fontSize' : '15px',
                    #'margin-top': '400px',
                    'margin-left': '100px',
                   }

# Step 4. Create a Dash layout
app.layout = html.Div([
                # a header and a paragraph
                html.Div([
                    html.H1("Simulation Tool"),
                   
                         ],
                     style = {'padding' : '50px' ,
                              'padding-left' : '35%',
                              'backgroundColor' : '#3aaab2'}),
                # adding a plot
                dcc.Graph(id = 'plot', figure = fig),
        

                # range slider
                html.P([
                    html.Label("Time Period"),
                    dcc.RangeSlider(id = 'slider',
                                    marks = {i : dates[i] for i in range(0, 9)},
                                    min = 0,
                                    max = 8,
                                    value = [1, 7])
                        ], style = {'width' : '80%',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),  
                # dropdown
                html.P([
                    html.Label("Select Province"),
                    dcc.Dropdown(id = 'opt', options = opts,
                                value = opts[0])
                        ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}),
                #button
               html.Div(
                    children=[
                    dbc.Button("Forecast", id="loading-button", style = red_button_style),
                    dcc.Loading(id="loading-output",
                            type="default",
                            children=html.Div(id="loading-output-1")
                                ),
                            ],
                        )
           
    
                      ])


# Step 5. Add callback functions
@app.callback(Output('plot', 'figure'),
             [Input('opt', 'value'),
             Input('slider', 'value')])

def update_figure(input1, input2):
    # filtering the data
    st2 = st[(st.Date > dates[input2[0]]) & (st.Date < dates[input2[1]])]
    # updating the plot
    trace_1 = go.Scatter(x = st2.Date, y = st2['Gauteng'],
                        name = 'Gauteng',
                        line = dict(width = 2,
                                    color = 'rgb(229, 151, 50)'))
    trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
                        name = input1,
                        line = dict(width = 2,
                                    color = 'rgb(106, 181, 135)'))
    fig = go.Figure(data = [trace_1, trace_2], layout = layout)
    return fig

@app.callback(
    Output("loading-output", "children"), [Input("loading-button", "n_clicks")]
)
def load_output(n):
    if n == 1:
        time.sleep(5)
        return  html.Div([  
    
    dcc.Graph(id= 'mpg-scatter',figure=fig1),
    html.Div(className='row', children=[
    html.Div([dcc.Markdown(d("""
              Click on point in the graph to display value.
            """)),
            html.Pre(id='hover-data'),
            ], className='three columns'),
            ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}, ) ,
             ])

    if n == 2:
        time.sleep(5)
        return html.Div([  
    
    dcc.Graph(id= 'mpg-scatter',figure=fig2),
    html.Div(className='row', children=[
    html.Div([dcc.Markdown(d("""
              Click on point in the graph to display value.
            """)),
            html.Pre(id='hover-data'),
            ], className='three columns'),
            ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}, ) ,
             ])
    if n == 3:
        time.sleep(5)
        return html.Div([  
    
    dcc.Graph(id= 'mpg-scatter',figure=fig3),
    html.Div(className='row', children=[
    html.Div([dcc.Markdown(d("""
              Click on point in the graph to display value.
            """)),
            html.Pre(id='hover-data'),
            ], className='three columns'),
            ], style = {'width': '400px',
                                    'fontSize' : '20px',
                                    'padding-left' : '100px',
                                    'display': 'inline-block'}, ) ,
             ])
    else:
        return None
@app.callback(
    Output('hover-data', 'children'),
    [Input('mpg-scatter', 'hoverData')])

def display_hover_data(hoverData):
    try: 
        return json.dumps({'Date:':hoverData['points'][0]['x'],
                           'SPEI Index:':hoverData['points'][0]['y'],
                          'Category': 'Severe drought'}, indent = 2)
    except: 
        return None  
# Step 6. Add the server clause
if __name__ == '__main__':
    app.run_server()
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Nov/2020 12:40:31] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:31] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:31] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:31] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 111, in update_figure
#     trace_2 = go.Scatter(x = st2.Date, y = st2[input1],
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/frame.py", line 2908, in __getitem__
#     indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1254, in _get_listlike_indexer
#     self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/pandas/core/indexing.py", line 1298, in _validate_read_indexer
#     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
# KeyError: "None of [Index(['label', 'value'], dtype='object')] are in the [columns]"
# 127.0.0.1 - - [15/Nov/2020 12:40:32] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [15/Nov/2020 12:40:34] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 123, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
# ...
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/_compat.py", line 39, in reraise
#     raise value
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/flask/app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1076, in dispatch
#     response.set_data(func(*args, outputs_list=outputs_list))
#   File "/Users/yolanda/opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages/dash/dash.py", line 1007, in add_context
#     output_value = func(*args, **kwargs)  # %% callback invoked %%
#   File "<ipython-input-41-3a3f90106cd5>", line 156, in load_output
#     time.sleep(5)
# NameError: name 'time' is not defined
# 127.0.0.1 - - [15/Nov/2020 12:40:36] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [15/Nov/2020 12:40:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:37] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:38] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Nov/2020 12:40:38] "POST /_dash-update-component HTTP/1.1" 200 -

# %%
df_proj.iloc[778:790,0].values
# Out:
# array([-3.54767752, -2.41444683, -1.49650204, -0.04785198,  0.41872528,
#         0.76872164,  0.21111515, -0.62045312, -1.75330293, -1.06695569,
#        -0.61249214, -1.13451838])

# %%
plot_data2 = [

    go.Scatter(
        x=df_proj.iloc[790:802,1].index,
        y=df_proj.iloc[778:790,0].values,
        name='prediction',
        line=dict(color="red")
    )
]

plot_layout2 = go.Layout(
        title=' Gauteng Drought Prediction'
    )
fig2 = go.Figure(data=plot_data2, layout=plot_layout2)

# %%
plot_data3 = [

    go.Scatter(
        x=df_proj.iloc[790:802,1].index,
        y=df_proj.iloc[766:778,0].values,
        name='prediction',
        line=dict(color="orange")
    )
]

plot_layout3 = go.Layout(
        title='Limpopo Drought Prediction'
    )
fig3 = go.Figure(data=plot_data3, layout=plot_layout3)

# %%
                    html.Div([
                    html.P("SPEI Index Forecasted"),],
                     style = {'position' : 'absolute' ,
                              "top": '835px',
                              'padding-left' : '35%',
                             'fontSize' : '15px'}),

# %%
st
# Out:
#      Unnamed: 0   Gauteng  North West  Free State  Easten Cape  Northen Cape  \
# 0             0  0.425023    1.258654    1.308560     0.201542      1.148724
# 1             1  0.829070    1.582015    1.222175     0.446709      1.587518
# 2             2  1.013218    1.840210    1.146903     0.150899      1.466218
# 3             3  0.986180    1.591472    0.222520    -0.060081      0.726476
# 4             4  0.491640    1.358973    0.341734    -0.326442     -0.040757
# ..          ...       ...         ...         ...          ...           ...
# 785         785 -0.620453   -1.280528   -1.871394    -0.346155     -0.498172
# 786         786 -1.753303   -1.466877   -2.437110    -1.237784     -1.104386
# 787         787 -1.066956   -0.393338   -0.858317    -0.358591     -0.141923
# 788         788 -0.612492   -0.527698   -0.451666    -0.516720     -0.635805
# 789         789 -1.134518   -1.734244   -1.588255    -1.465679     -1.400731
#
#       Limpopo       Date
# 0    0.945695 1955-01-01
# 1    1.288835 1955-02-01
# 2    1.321592 1955-03-01
# 3    0.696104 1955-04-01
# 4    0.049011 1955-05-01
# ..        ...        ...
# 785 -0.754704 2020-06-01
# 786 -1.687257 2020-07-01
# 787 -0.962879 2020-08-01
# 788 -0.769770 2020-09-01
# 789 -0.968466 2020-10-01
#
# [790 rows x 8 columns]

# %%
pip install dash_bootstrap_components
# Out:
# Collecting dash_bootstrap_components
#   Using cached dash_bootstrap_components-0.10.7-py2.py3-none-any.whl (185 kB)
# Requirement already satisfied: dash>=1.9.0 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash_bootstrap_components) (1.17.0)
# Requirement already satisfied: flask-compress in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (1.8.0)
# Requirement already satisfied: future in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (0.18.2)
# Requirement already satisfied: dash-renderer==1.8.3 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (1.8.3)
# Requirement already satisfied: dash-html-components==1.1.1 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (1.1.1)
# Requirement already satisfied: dash-table==4.11.0 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (4.11.0)
# Requirement already satisfied: plotly in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (4.12.0)
# Requirement already satisfied: dash-core-components==1.13.0 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (1.13.0)
# Requirement already satisfied: Flask>=1.0.2 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from dash>=1.9.0->dash_bootstrap_components) (1.1.2)
# Requirement already satisfied: brotli in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from flask-compress->dash>=1.9.0->dash_bootstrap_components) (1.0.9)
# Requirement already satisfied: six in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from plotly->dash>=1.9.0->dash_bootstrap_components) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from plotly->dash>=1.9.0->dash_bootstrap_components) (1.3.3)
# Requirement already satisfied: itsdangerous>=0.24 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.9.0->dash_bootstrap_components) (1.1.0)
# Requirement already satisfied: click>=5.1 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.9.0->dash_bootstrap_components) (7.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.9.0->dash_bootstrap_components) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from Flask>=1.0.2->dash>=1.9.0->dash_bootstrap_components) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in ./opt/anaconda3/envs/watwer-base/lib/python3.7/site-packages (from Jinja2>=2.10.1->Flask>=1.0.2->dash>=1.9.0->dash_bootstrap_components) (1.1.1)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-0.10.7
# Note: you may need to restart the kernel to use updated packages.
